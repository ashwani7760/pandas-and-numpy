# %%
import pandas as pd

# %%
d1  = {'key1' : [1,2,3,4,5],
      "key2" : [6,7,8,9,10],
      "key3" : [11,12,13,"ash",15]}

# %%
data1 = pd.DataFrame(d1)

# %%
d2  = {'key1' : [1,2,"ap",4,5],
      "key2" : [6,7,"sd",9,10],
      "key3" : [11,"as",13,"ash",15]}

# %%
data2 = pd.DataFrame(d2)

# %%
print(data1)
print(data2)
# Out:
#    key1  key2 key3
# 0     1     6   11
# 1     2     7   12
# 2     3     8   13
# 3     4     9  ash
# 4     5    10   15
#   key1 key2 key3
# 0    1    6   11
# 1    2    7   as
# 2   ap   sd   13
# 3    4    9  ash
# 4    5   10   15

# %%
pd.merge(data1,data2)  # by default how = inner     inner like intersection in set       data1 consider as left and other right
# Out:
#   key1 key2 key3
# 0    1    6   11
# 1    4    9  ash
# 2    5   10   15

# %%
pd.merge(data1,data2,how = "inner",on = "key1")
# Out:
#   key1  key2_x key3_x key2_y key3_y
# 0    1       6     11      6     11
# 1    2       7     12      7     as
# 2    4       9    ash      9    ash
# 3    5      10     15     10     15

# %%
pd.merge(data1,data2,how = "left",on = "key1")
# Out:
#   key1  key2_x key3_x key2_y key3_y
# 0    1       6     11      6     11
# 1    2       7     12      7     as
# 2    3       8     13    NaN    NaN
# 3    4       9    ash      9    ash
# 4    5      10     15     10     15

# %%
pd.merge(data1,data2,how = "right",on = "key1")
# Out:
#   key1  key2_x key3_x key2_y key3_y
# 0    1     6.0     11      6     11
# 1    2     7.0     12      7     as
# 2   ap     NaN    NaN     sd     13
# 3    4     9.0    ash      9    ash
# 4    5    10.0     15     10     15

# %%
pd.merge(data1,data2,how = "outer",on = "key1")
# Out:
#   key1  key2_x key3_x key2_y key3_y
# 0    1     6.0     11      6     11
# 1    2     7.0     12      7     as
# 2    3     8.0     13    NaN    NaN
# 3    4     9.0    ash      9    ash
# 4    5    10.0     15     10     15
# 5   ap     NaN    NaN     sd     13

# %%
d1  = {'a' : [1,2,3,4,5],
      "b" : [6,7,8,9,10],
      "c" : [11,12,13,"ash",15]}

d2  = {'key1' : [1,2,"ap",4,5],
      "key2" : [6,7,"sd",9,10],
      "key3" : [11,"as",13,"ash",15]}

df11 = pd.DataFrame(d1)
df12 = pd.DataFrame(d2)

# %% [markdown]
# # how to join when not any column name is common in both dataframe

# %%
pd.merge(df11,df12,how="inner",on= "key1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8472\1317364368.py in ?()
# ----> 1 pd.merge(df11,df12,how="inner",on= "key1")
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1307                     if lk is not None:
#    1308                         # Then we're either Hashable or a wrong-length arraylike,
#    1309                         #  the latter of which will raise
#    1310                         lk = cast(Hashable, lk)
# -> 1311                         left_keys.append(left._get_label_or_level_values(lk))
#    1312                         join_names.append(lk)
#    1313                     else:
#    1314                         # work-around for merge_asof(left_index=True)
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'key1'

# %%
pd.merge(df11,df12,how="inner",left_on= "a", right_on = "key1")
# Out:
#    a   b    c key1 key2 key3
# 0  1   6   11    1    6   11
# 1  2   7   12    2    7   as
# 2  4   9  ash    4    9  ash
# 3  5  10   15    5   10   15

# %%
df11
# Out:
#    a   b    c
# 0  1   6   11
# 1  2   7   12
# 2  3   8   13
# 3  4   9  ash
# 4  5  10   15

# %%
df12
# Out:
#   key1 key2 key3
# 0    1    6   11
# 1    2    7   as
# 2   ap   sd   13
# 3    4    9  ash
# 4    5   10   15

# %% [markdown]
# # join always try to focus on index and merge focus on column name

# %%
# join work when col name of each df is different but in merge not get problem

# %%
df11.join(df12)
# Out:
#    a   b    c key1 key2 key3
# 0  1   6   11    1    6   11
# 1  2   7   12    2    7   as
# 2  3   8   13   ap   sd   13
# 3  4   9  ash    4    9  ash
# 4  5  10   15    5   10   15

# %% [markdown]
# # insert column

# %%
df11
# Out:
#    a   b    c
# 0  1   6   11
# 1  2   7   12
# 2  3   8   13
# 3  4   9  ash
# 4  5  10   15

# %%
df11.insert(1,"abc",df11["a"]*2)

# %%
df11
# Out:
#    a  abc   b    c
# 0  1    2   6   11
# 1  2    4   7   12
# 2  3    6   8   13
# 3  4    8   9  ash
# 4  5   10  10   15

# %% [markdown]
# # update value in dataframe

# %%
df11.loc[2,"b"]= 1000

# %%
df11
# Out:
#    a  abc     b    c
# 0  1    2     6   11
# 1  2    4     7   12
# 2  3    6  1000   13
# 3  4    8     9  ash
# 4  5   10    10   15

# %%
import numpy as np
import pandas as pd

# %%
l = [1,2,2,4,5,2]

# %%
type(l)
# Out:
# list

# %%
a = np.array(l)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a1 =np.array([[1,2,3],[4,5,6]])

# %%
a2  =np.array([[[1,2,3],[7,8,9]],[[4,5,6],[1,5,9]]])

# %% [markdown]
# # check dim of array

# %%
a.ndim
# Out:
# 1

# %%
a1.ndim
# Out:
# 2

# %%
a2.ndim
# Out:
# 3

# %%
a2
# Out:
# array([[[1, 2, 3],
#         [7, 8, 9]],
#
#        [[4, 5, 6],
#         [1, 5, 9]]])

# %%
# asarray, asmatrix

# %%
l  = [1,2,3,3]

# %%
np.asarray(l) # only one d
# Out:
# array([1, 2, 3, 3])

# %%
np.asmatrix(l) # atleast 2d
# Out:
# matrix([[1, 2, 3, 3]])

# %% [markdown]
# # deep copy and shallow copy

# %%
a
# Out:
# array([1, 2, 2, 4, 5, 2])

# %%
a1 =a # shallow copy if make change in any of them make changes in both

# %%
a1
# Out:
# array([1, 2, 2, 4, 5, 2])

# %%
a[0]
# Out:
# np.int64(1)

# %%
a[0]=10

# %%
a
# Out:
# array([10,  2,  2,  4,  5,  2])

# %%
a1
# Out:
# array([10,  2,  2,  4,  5,  2])

# %%
a[1]=50

# %%
a
# Out:
# array([10, 50,  2,  4,  5,  2])

# %%
a1
# Out:
# array([10, 50,  2,  4,  5,  2])

# %%
a2  =np.copy(a) # deep copy

# %%
a2
# Out:
# array([10, 50,  2,  4,  5,  2])

# %%
a2[1]= 100

# %%
a2
# Out:
# array([ 10, 100,   2,   4,   5,   2])

# %%
a
# Out:
# array([10, 50,  2,  4,  5,  2])

# %% [markdown]
# # from function

# %%
np.fromfunction(lambda i,j : i==j,(3,4))
# Out:
# array([[ True, False, False, False],
#        [False,  True, False, False],
#        [False, False,  True, False]])

# %%
np.random.rand(3,2)
# Out:
# array([[0.49392887, 0.53376592],
#        [0.233076  , 0.03019734],
#        [0.8919386 , 0.56284901]])

# %%
np.random.rand(4,3,2) #(z,x,y)
# Out:
# array([[[0.15905582, 0.4883729 ],
#         [0.46547498, 0.6079181 ],
#         [0.08089889, 0.34227803]],
#
#        [[0.82848997, 0.74934567],
#         [0.44068125, 0.93898905],
#         [0.38450578, 0.87971239]],
#
#        [[0.096722  , 0.28089066],
#         [0.34936855, 0.25489163],
#         [0.66685293, 0.02033032]],
#
#        [[0.7289346 , 0.07393875],
#         [0.3072951 , 0.95948871],
#         [0.86049548, 0.03633196]]])

# %%
np.random.randn(4,3,2)# randn generate with mean  = 0  , std = 1
# Out:
# array([[[ 0.49728997,  0.01534496],
#         [ 1.44584615,  0.33532253],
#         [ 0.32308684,  1.7919504 ]],
#
#        [[-0.57232454,  1.97640519],
#         [-1.424585  ,  0.54056946],
#         [-0.09549453,  0.60300256]],
#
#        [[-1.93682526, -1.50954077],
#         [-0.28565928,  0.27538914],
#         [ 1.01590016,  0.38326838]],
#
#        [[ 1.57391336,  1.17528636],
#         [-0.08071137,  0.01041141],
#         [-0.04506329, -0.15369761]]])

# %%
np.random.randint(0,10,(4,2,5)) # between 0 and 10 matrix z,x,y
# Out:
# array([[[7, 4, 5, 7, 2],
#         [8, 6, 4, 5, 2]],
#
#        [[6, 8, 4, 4, 0],
#         [0, 9, 6, 8, 9]],
#
#        [[4, 9, 2, 2, 3],
#         [4, 0, 4, 0, 1]],
#
#        [[2, 1, 7, 1, 8],
#         [2, 1, 0, 3, 3]]], dtype=int32)

# %% [markdown]
# # nd convert to 2d array

# %%
d =np.random.randint(0,10,(4,2,5))

# %%
d
# Out:
# array([[[5, 3, 2, 7, 7],
#         [7, 0, 3, 8, 2]],
#
#        [[4, 0, 3, 3, 6],
#         [4, 4, 1, 4, 1]],
#
#        [[0, 0, 8, 7, 1],
#         [6, 5, 2, 5, 5]],
#
#        [[1, 0, 3, 1, 8],
#         [1, 7, 2, 4, 2]]], dtype=int32)

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pd.DataFrame(d)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     820         mgr = dict_to_mgr(
#     821             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     822             # attribute "name"
#    (...)    828             copy=_copy,
#     829         )
#     830     else:
# --> 831         mgr = ndarray_to_mgr(
#     832             data,
#     833             index,
#     834             columns,
#     835             dtype=dtype,
#     836             copy=copy,
#     837             typ=manager,
#     838         )
#     840 # For data is list-like, or Iterable (will consume into list)
#     841 elif is_list_like(data):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:314, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     312     else:
#     313         values = np.asarray(values)
# --> 314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
#     319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:592, in _ensure_2d(values)
#     590     values = values.reshape((values.shape[0], 1))
#     591 elif values.ndim != 2:
# --> 592     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=(4, 2, 5)

# %%
np.reshape(d,(8,5))
# Out:
# array([[5, 3, 2, 7, 7],
#        [7, 0, 3, 8, 2],
#        [4, 0, 3, 3, 6],
#        [4, 4, 1, 4, 1],
#        [0, 0, 8, 7, 1],
#        [6, 5, 2, 5, 5],
#        [1, 0, 3, 1, 8],
#        [1, 7, 2, 4, 2]], dtype=int32)

# %%
d.reshape(8,-2)
# Out:
# array([[5, 3, 2, 7, 7],
#        [7, 0, 3, 8, 2],
#        [4, 0, 3, 3, 6],
#        [4, 4, 1, 4, 1],
#        [0, 0, 8, 7, 1],
#        [6, 5, 2, 5, 5],
#        [1, 0, 3, 1, 8],
#        [1, 7, 2, 4, 2]], dtype=int32)
