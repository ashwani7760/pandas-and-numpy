# %% [markdown]
# # import pandas library

# %%
import pandas as pd

# %% [markdown]
# # read data from files

# %%
df = pd.read_csv(r"C:\Users\dellp\Downloads\data.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# # create series and dataframe

# %%
# from list
pd.Series([6,1,"8",1,1.2],index = [1,2,3,4,5])
# Out:
# 1      6
# 2      1
# 3      8
# 4      1
# 5    1.2
# dtype: object

# %%
#from dictionary
pd.Series({1:23,
          2:45,
          3:21})
# Out:
# 1    23
# 2    45
# 3    21
# dtype: int64

# %%
# create dataframe
data = {"name":["x","y","z"],
       "age":[19,15,20],
       "gender":["m","f","m"]}
d = pd.DataFrame(data)

# %%
d
# Out:
#   name  age gender
# 0    x   19      m
# 1    y   15      f
# 2    z   20      m

# %% [markdown]
# # Save output

# %%
d.to_csv("df.csv")

# %% [markdown]
# # head, tail, info, describe, shape, columns

# %%
df.head() # top 5 rows
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
#if want to change data type of any column

# %%
df.tail() # bottom 5 rows
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
df.shape # shape of dataframe
# Out:
# (32, 5)

# %%
df.columns # list of columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.info() # info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.describe() # stats of numeric values only
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# # read function take first row of data as an header and if data has no columns name in this case no need of header

# %%
df = pd.read_csv(r"C:\Users\dellp\Downloads\titanic.csv",header = None)
df.head()
# Out:
#    0   1   2                                                  3       4   \
# 0   1   0   3                            Braund, Mr. Owen Harris    male
# 1   2   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2   3   1   3                             Heikkinen, Miss. Laina  female
# 3   4   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4   5   0   3                           Allen, Mr. William Henry    male
#
#      5   6   7                 8        9     10 11
# 0  22.0   1   0         A/5 21171   7.2500   NaN  S
# 1  38.0   1   0          PC 17599  71.2833   C85  C
# 2  26.0   0   0  STON/O2. 3101282   7.9250   NaN  S
# 3  35.0   1   0            113803  53.1000  C123  S
# 4  35.0   0   0            373450   8.0500   NaN  S

# %% [markdown]
# ## if want to give column name

# %%
df = pd.read_csv(r"C:\Users\dellp\Downloads\titanic.csv",names =["a","b","c","place","d","e","f","g","h","i","j","k"])
df.head()
# Out:
#    a  b  c                                              place       d     e  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    f  g                 h        i     j  k
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
# if given name is less than no. of column then the first remaining columns consider as row index

# %%
# if given name is more than no. of column then create a columns with all row value as nan

# %% [markdown]
# # csv seperatar

# %%
# if have csv file where is data is not seperated by comman and sep by @

# %%
# pd.read_csv("text.csx",sep = "@")

# %%
df = pd.read_csv(r"C:\Users\dellp\Downloads\titanic.csv",header = None , skiprows = [1,3])

# %%
df
# Out:
#    0   1   2                                                  3       4   \
# 0   1   0   3                            Braund, Mr. Owen Harris    male
# 1   3   1   3                             Heikkinen, Miss. Laina  female
# 2   5   0   3                           Allen, Mr. William Henry    male
# 3   6   0   3                                   Moran, Mr. James    male
# 4   7   0   1                            McCarthy, Mr. Timothy J    male
# 5   8   0   3                     Palsson, Master. Gosta Leonard    male
# 6   9   1   3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 7  10   1   2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 8  11   1   3                    Sandstrom, Miss. Marguerite Rut  female
# 9  12   1   1                           Bonnell, Miss. Elizabeth  female
#
#      5   6   7                 8        9     10 11
# 0  22.0   1   0         A/5 21171   7.2500   NaN  S
# 1  26.0   0   0  STON/O2. 3101282   7.9250   NaN  S
# ...

# %% [markdown]
# # view

# %%
df = pd.read_csv(r"C:\Users\dellp\Downloads\data.csv")

# %%
df.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df[["Date","Maxpulse"]].head()
# Out:
#            Date  Maxpulse
# 0  '2020/12/01'       130
# 1  '2020/12/02'       145
# 2  '2020/12/03'       135
# 3  '2020/12/04'       175
# 4  '2020/12/05'       148

# %%
a = df[["Date","Maxpulse"]].head()
type(a)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # if excel file have multiple sheet how we access

# %%
df = pd.read_excel(r"C:\Users\dellp\Downloads\data1.xlsx",sheet_name = "data1")

# %%
df
# Out:
#    sdss    dssd      dds
# 0     1   dhdds   sjfdfh
# 1     5  ddsnnh      fdn
# 2     2  dshbnd     dmfm
# 3     3    dbsn  fgd ffg
# 4     2   fs fn      gdk

# %% [markdown]
# # if want to access all sheet and read data

# %%
df = pd.ExcelFile(r"C:\Users\dellp\Downloads\data1.xlsx")

# %%
df.sheet_names
# Out:
# ['data1']

# %%
for i in df.sheet_names:
    print(pd.read_excel(r"C:\Users\dellp\Downloads\data1.xlsx", sheet_name = i))
# Out:
#    sdss    dssd      dds
# 0     1   dhdds   sjfdfh
# 1     5  ddsnnh      fdn
# 2     2  dshbnd     dmfm
# 3     3    dbsn  fgd ffg
# 4     2   fs fn      gdk

# %%
# direct load data from github 
# pd.read_csv("address")
