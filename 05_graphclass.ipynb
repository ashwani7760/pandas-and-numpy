# %%
import cufflinks as cf
import numpy as np
import pandas as pd
import seaborn as sns

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randint(1,100,(100,3)), columns = ["a","b","c"])

# %%
df
# Out:
#      a   b   c
# 0   47  90  53
# 1    2  71  74
# 2    7  68   2
# 3   42  20  17
# 4   17  32  55
# ..  ..  ..  ..
# 95  64  78  70
# 96  85  57  54
# 97  31  96  50
# 98  66  20   5
# 99   8  26  90
#
# [100 rows x 3 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x= df["sex"] , y = df["survived"])
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
tip  = sns.load_dataset("tips")
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(tip, x = "total_bill" , y = "tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tip, x = "total_bill" , y = "tip",hue = "smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tip, x = "total_bill" , y = "tip",style = "size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
iris =  sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x= "sepal_length" ,  y = "sepal_width" , data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x= "sepal_length" ,  y = "petal_width" , data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
iris.plot(figsize = (20,10), title = "iris plot graph" )
# Out:
# <Axes: title={'center': 'iris plot graph'}>

# %%
iris["sepal_length"].hist()  # x range  of values   y count of value lie in range
# Out:
# <Axes: >
